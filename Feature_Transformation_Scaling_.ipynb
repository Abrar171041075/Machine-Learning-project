# %% [markdown]
# <a href="https://colab.research.google.com/github/Abrar171041075/Machine-Learning-project/blob/main/Feature_Transformation_Scaling_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-d3c8e9b8-8ad3-404d-9bd9-51c0d590a28b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3c8e9b8-8ad3-404d-9bd9-51c0d590a28b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving supershops.csv to supershops (3).csv
# ...

# %%
df = pd.read_csv('supershops.csv')

# %%
df.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80  471784.10    Dhaka  192261.83
# 1        162597.70       151377.59  443898.53      Ctg  191792.06
# 2        153441.51       101145.55  407934.54  Rangpur  191050.39
# 3        144372.41       118671.85  383199.62    Dhaka  182901.99
# 4        142107.34        91391.77  366168.42  Rangpur  166187.94

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          1
# Area               0
# Profit             0
# dtype: int64

# %%
df.shape
# Out:
# (50, 5)

# %%
df.Transport
# Out:
# 0     471784.10
# 1     443898.53
# 2     407934.54
# 3     383199.62
# 4     366168.42
# 5     362861.36
# 6     127716.82
# 7     323876.68
# 8     311613.29
# 9     304981.62
# 10    229160.95
# 11    249744.55
# 12    249839.44
# 13    252664.93
# 14    256512.92
# 15    261776.23
# 16    264346.06
# 17    282574.31
# 18    294919.57
# 19          NaN
# 20    298664.47
# 21    299737.29
# 22    303319.26
# 23    304768.73
# 24    140574.81
# 25    137962.62
# 26    134050.07
# 27    353183.81
# 28    118148.20
# 29    107138.38
# 30     91131.24
# 31     88218.23
# 32     46085.25
# 33    214634.81
# 34    210797.67
# 35    205517.64
# 36    201126.82
# 37    197029.42
# 38    185265.10
# 39    174999.30
# 40    172795.67
# 41    164470.71
# 42    148001.11
# 43     35534.17
# 44     28334.72
# 45      1903.93
# 46    297114.46
# 47         0.00
# 48         0.00
# 49     45173.06
# Name: Transport, dtype: float64

# %%
df.describe()
# Out:
#        Marketing Spend  Administration      Transport         Profit
# count        50.000000       50.000000      49.000000      50.000000
# mean      73721.615600   121344.639600  215331.732449  112012.639200
# std       45902.256482    28017.802755  119665.391550   40306.180338
# min           0.000000    51283.140000       0.000000   14681.400000
# 25%       39936.370000   103730.875000  134050.070000   90138.902500
# 50%       73051.080000   122699.795000  214634.810000  107978.190000
# 75%      101602.800000   144842.180000  299737.290000  139765.977500
# max      165349.200000   182645.560000  471784.100000  192261.830000

# %%
df.isnull().sum().plot.hist()

# %%
#handle NaN value 

mean = df.Transport.mean()

median = df.Transport.median()

# %%
median
# Out:
# 214634.81

# %%
df.Transport = df.Transport.fillna(median)

# %%
df.isnull().sum()
# Out:
# Marketing Spend    0
# Administration     0
# Transport          0
# Area               0
# Profit             0
# dtype: int64

# %%
df1 = df.copy()
df2 = df.copy()
df3 = df.copy()
df4 = df.copy()
df5 = df.copy()

# %% [markdown]
# # Nomalization

# %%
from sklearn.preprocessing import MinMaxScaler
norm=MinMaxScaler()

# %%
df1.columns
# Out:
# Index(['Marketing Spend', 'Administration', 'Transport', 'Area', 'Profit'], dtype='object')

# %%
df1['Marketing Spend'] = norm.fit_transform(df[['Marketing Spend']])

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617       136897.80  471784.10    Dhaka  192261.83
# 1         0.983359       151377.59  443898.53      Ctg  191792.06
# 2         0.927985       101145.55  407934.54  Rangpur  191050.39
# 3         0.873136       118671.85  383199.62    Dhaka  182901.99
# 4         0.859438        91391.77  366168.42  Rangpur  166187.94

# %%
df1['Administration'] = norm.fit_transform(df1[['Administration']])

# %%
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.692617        0.651744  471784.10    Dhaka  192261.83
# 1         0.983359        0.761972  443898.53      Ctg  191792.06
# 2         0.927985        0.379579  407934.54  Rangpur  191050.39
# 3         0.873136        0.512998  383199.62    Dhaka  182901.99
# 4         0.859438        0.305328  366168.42  Rangpur  166187.94

# %%
df1['Profit'] = norm.fit_transform(df1[['Profit']])
df1.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.651744  471784.10    Dhaka  1.000000
# 1         0.983359        0.761972  443898.53      Ctg  0.997355
# 2         0.927985        0.379579  407934.54  Rangpur  0.993178
# 3         0.873136        0.512998  383199.62    Dhaka  0.947292
# 4         0.859438        0.305328  366168.42  Rangpur  0.853171

# %%
df1
# Out:
#     Marketing Spend  Administration  Transport     Area    Profit
# 0          0.692617        0.651744  471784.10    Dhaka  1.000000
# 1          0.983359        0.761972  443898.53      Ctg  0.997355
# 2          0.927985        0.379579  407934.54  Rangpur  0.993178
# 3          0.873136        0.512998  383199.62    Dhaka  0.947292
# 4          0.859438        0.305328  366168.42  Rangpur  0.853171
# 5          0.797566        0.369448  362861.36    Dhaka  0.801382
# 6          0.814128        0.730161  127716.82      Ctg  0.796490
# 7          0.788018        0.717457  323876.68  Rangpur  0.794407
# 8          0.729018        0.741733  311613.29    Dhaka  0.774468
# 9          0.745906        0.436929  304981.62      Ctg  0.760661
# 10         0.616351        0.451506  229160.95  Rangpur  0.740175
# 11         0.608845        0.308364  249744.55      Ctg  0.729686
# 12         0.567670        0.578836  249839.44  Rangpur  0.714629
# ...

# %% [markdown]
# # Standardization

# %%
from sklearn.preprocessing import StandardScaler
standard_scale = StandardScaler()

# %%
df2['Marketing Spend'] = standard_scale.fit_transform(df2[['Marketing Spend']])

# %%
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0         0.897913       136897.80  471784.10    Dhaka  192261.83
# 1         1.955860       151377.59  443898.53      Ctg  191792.06
# 2         1.754364       101145.55  407934.54  Rangpur  191050.39
# 3         1.554784       118671.85  383199.62    Dhaka  182901.99
# 4         1.504937        91391.77  366168.42  Rangpur  166187.94

# %%
df2['Profit'] = standard_scale.fit_transform(df2[['Profit']])
df2.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.897913       136897.80  471784.10    Dhaka  2.011203
# 1         1.955860       151377.59  443898.53      Ctg  1.999430
# 2         1.754364       101145.55  407934.54  Rangpur  1.980842
# 3         1.554784       118671.85  383199.62    Dhaka  1.776627
# 4         1.504937        91391.77  366168.42  Rangpur  1.357740

# %% [markdown]
# # Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler
RoSc=RobustScaler()

# %%
df3
# Out:
#     Marketing Spend  Administration  Transport     Area     Profit
# 0         114523.61       136897.80  471784.10    Dhaka  192261.83
# 1         162597.70       151377.59  443898.53      Ctg  191792.06
# 2         153441.51       101145.55  407934.54  Rangpur  191050.39
# 3         144372.41       118671.85  383199.62    Dhaka  182901.99
# 4         142107.34        91391.77  366168.42  Rangpur  166187.94
# 5         131876.90        99814.71  362861.36    Dhaka  156991.12
# 6         134615.46       147198.87  127716.82      Ctg  156122.51
# 7         130298.13       145530.06  323876.68  Rangpur  155752.60
# 8         120542.52       148718.95  311613.29    Dhaka  152211.77
# 9         123334.88       108679.17  304981.62      Ctg  149759.96
# 10        101913.08       110594.11  229160.95  Rangpur  146121.95
# 11        100671.96        91790.61  249744.55      Ctg  144259.40
# 12         93863.75       127320.38  249839.44  Rangpur  141585.52
# ...

# %%
df3['Profit'] = RoSc.fit_transform(df3[['Profit']])
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0        114523.61       136897.80  471784.10    Dhaka  1.698340
# 1        162597.70       151377.59  443898.53      Ctg  1.688874
# 2        153441.51       101145.55  407934.54  Rangpur  1.673929
# 3        144372.41       118671.85  383199.62    Dhaka  1.509736
# 4        142107.34        91391.77  366168.42  Rangpur  1.172943

# %%
df3['Transport'] = RoSc.fit_transform(df3[['Transport']])
df3.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0        114523.61       136897.80   1.563780    Dhaka  1.698340
# 1        162597.70       151377.59   1.394202      Ctg  1.688874
# 2        153441.51       101145.55   1.175497  Rangpur  1.673929
# 3        144372.41       118671.85   1.025079    Dhaka  1.509736
# 4        142107.34        91391.77   0.921508  Rangpur  1.172943

# %%
df3
# Out:
#     Marketing Spend  Administration  Transport     Area    Profit
# 0         114523.61       136897.80   1.563780    Dhaka  1.698340
# 1         162597.70       151377.59   1.394202      Ctg  1.688874
# 2         153441.51       101145.55   1.175497  Rangpur  1.673929
# 3         144372.41       118671.85   1.025079    Dhaka  1.509736
# 4         142107.34        91391.77   0.921508  Rangpur  1.172943
# 5         131876.90        99814.71   0.901397    Dhaka  0.987625
# 6         134615.46       147198.87  -0.528567      Ctg  0.970122
# 7         130298.13       145530.06   0.664323  Rangpur  0.962668
# 8         120542.52       148718.95   0.589747    Dhaka  0.891320
# 9         123334.88       108679.17   0.549418      Ctg  0.841915
# 10        101913.08       110594.11   0.088337  Rangpur  0.768608
# 11        100671.96        91790.61   0.213510      Ctg  0.731077
# 12         93863.75       127320.38   0.214087  Rangpur  0.677197
# ...

# %% [markdown]
# # Max Absolute Scalar

# %%
from sklearn.preprocessing import MaxAbsScaler
MA_scaler=MaxAbsScaler()

# %%
df4['Transport'] = MA_scaler.fit_transform(df4[['Transport']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area     Profit
# 0        114523.61       136897.80   1.000000    Dhaka  192261.83
# 1        162597.70       151377.59   0.940893      Ctg  191792.06
# 2        153441.51       101145.55   0.864664  Rangpur  191050.39
# 3        144372.41       118671.85   0.812235    Dhaka  182901.99
# 4        142107.34        91391.77   0.776136  Rangpur  166187.94

# %%
df4['Profit'] = MA_scaler.fit_transform(df4[['Profit']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0        114523.61       136897.80   1.000000    Dhaka  1.000000
# 1        162597.70       151377.59   0.940893      Ctg  0.997557
# 2        153441.51       101145.55   0.864664  Rangpur  0.993699
# 3        144372.41       118671.85   0.812235    Dhaka  0.951317
# 4        142107.34        91391.77   0.776136  Rangpur  0.864383

# %%
df4['Marketing Spend'] = MA_scaler.fit_transform(df4[['Marketing Spend']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617       136897.80   1.000000    Dhaka  1.000000
# 1         0.983359       151377.59   0.940893      Ctg  0.997557
# 2         0.927985       101145.55   0.864664  Rangpur  0.993699
# 3         0.873136       118671.85   0.812235    Dhaka  0.951317
# 4         0.859438        91391.77   0.776136  Rangpur  0.864383

# %%
df4['Administration'] = MA_scaler.fit_transform(df4[['Administration']])
df4.head()
# Out:
#    Marketing Spend  Administration  Transport     Area    Profit
# 0         0.692617        0.749527   1.000000    Dhaka  1.000000
# 1         0.983359        0.828805   0.940893      Ctg  0.997557
# 2         0.927985        0.553781   0.864664  Rangpur  0.993699
# 3         0.873136        0.649738   0.812235    Dhaka  0.951317
# 4         0.859438        0.500378   0.776136  Rangpur  0.864383

# %%
df4
# Out:
#     Marketing Spend  Administration  Transport     Area    Profit
# 0          0.692617        0.749527   1.000000    Dhaka  1.000000
# 1          0.983359        0.828805   0.940893      Ctg  0.997557
# 2          0.927985        0.553781   0.864664  Rangpur  0.993699
# 3          0.873136        0.649738   0.812235    Dhaka  0.951317
# 4          0.859438        0.500378   0.776136  Rangpur  0.864383
# 5          0.797566        0.546494   0.769126    Dhaka  0.816549
# 6          0.814128        0.805926   0.270710      Ctg  0.812031
# 7          0.788018        0.796789   0.686493  Rangpur  0.810107
# 8          0.729018        0.814249   0.660500    Dhaka  0.791690
# 9          0.745906        0.595028   0.646443      Ctg  0.778938
# 10         0.616351        0.605512   0.485733  Rangpur  0.760015
# 11         0.608845        0.502561   0.529362      Ctg  0.750328
# 12         0.567670        0.697090   0.529563  Rangpur  0.736420
# ...
